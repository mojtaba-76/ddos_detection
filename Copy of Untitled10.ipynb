# %%
# !git clone https://github.com/uclnlp/APE
# Out:
# Cloning into 'APE'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 47 (delta 19), reused 47 (delta 19), pack-reused 0
# Unpacking objects: 100% (47/47), done.

# %%
# !git clone https://github.com/facebookresearch/FiD.git
# Out:
# Cloning into 'FiD'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 60 (delta 23), reused 39 (delta 14), pack-reused 3
# Unpacking objects: 100% (60/60), done.

# %%
# %%shell
# bash FiD/get-data.sh
# Out:
# Saving data in open_domain_data
# Downloading Wikipedia passages
# --2022-02-01 16:49:31--  https://dl.fbaipublicfiles.com/dpr/wikipedia_split/psgs_w100.tsv.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4694541059 (4.4G) [application/gzip]
# Saving to: ‘open_domain_data/download/psgs_w100.tsv.gz’
#
# psgs_w100.tsv.gz    100%[===================>]   4.37G  62.7MB/s    in 83s
#
# 2022-02-01 16:50:54 (54.0 MB/s) - ‘open_domain_data/download/psgs_w100.tsv.gz’ saved [4694541059/4694541059]
#
# Decompressing Wikipedia passages
# --2022-02-01 16:55:56--  https://raw.githubusercontent.com/google-research-datasets/natural-questions/master/nq_open/NQ-open.dev.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 391316 (382K) [text/plain]
# Saving to: ‘open_domain_data/download/NQ-open.dev.jsonl’
#
# NQ-open.dev.jsonl   100%[===================>] 382.14K  --.-KB/s    in 0.03s
#
# 2022-02-01 16:55:56 (11.0 MB/s) - ‘open_domain_data/download/NQ-open.dev.jsonl’ saved [391316/391316]
#
# --2022-02-01 16:55:56--  https://raw.githubusercontent.com/google-research-datasets/natural-questions/master/nq_open/NQ-open.train.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8522298 (8.1M) [text/plain]
# Saving to: ‘open_domain_data/download/NQ-open.train.jsonl’
#
# NQ-open.train.jsonl 100%[===================>]   8.13M  --.-KB/s    in 0.09s
#
# 2022-02-01 16:55:56 (93.2 MB/s) - ‘open_domain_data/download/NQ-open.train.jsonl’ saved [8522298/8522298]
#
# --2022-02-01 16:55:56--  http://nlp.cs.washington.edu/triviaqa/data/triviaqa-unfiltered.tar.gz
# Resolving nlp.cs.washington.edu (nlp.cs.washington.edu)... 128.208.3.120, 2607:4000:200:12::78
# Connecting to nlp.cs.washington.edu (nlp.cs.washington.edu)|128.208.3.120|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 632549060 (603M) [application/x-gzip]
# Saving to: ‘open_domain_data/download/triviaqa-unfiltered.tar.gz’
#
# triviaqa-unfiltered 100%[===================>] 603.25M  28.7MB/s    in 22s
#
# 2022-02-01 16:56:18 (27.9 MB/s) - ‘open_domain_data/download/triviaqa-unfiltered.tar.gz’ saved [632549060/632549060]
#
# triviaqa-unfiltered/
# triviaqa-unfiltered/unfiltered-web-train.json
# triviaqa-unfiltered/README
# triviaqa-unfiltered/unfiltered-web-dev.json
# triviaqa-unfiltered/unfiltered-web-test-without-answers.json
# --2022-02-01 16:57:13--  https://dl.fbaipublicfiles.com/FiD/data/dataindex.tar.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 483821 (472K) [application/gzip]
# Saving to: ‘open_domain_data/download/dataindex.tar.gz’
#
# dataindex.tar.gz    100%[===================>] 472.48K  2.16MB/s    in 0.2s
#
# 2022-02-01 16:57:15 (2.16 MB/s) - ‘open_domain_data/download/dataindex.tar.gz’ saved [483821/483821]
#
# NQ.dev.idx.json
# NQ.test.idx.json
# NQ.train.idx.json
# TQA.dev.idx.json
# TQA.test.idx.json
# TQA.train.idx.json
# --2022-02-01 16:57:15--  https://dl.fbaipublicfiles.com/FiD/data/nq_passages.tar.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35243587 (34M) [application/gzip]
# Saving to: ‘open_domain_data/download/nq_passages.tar.gz’
#
# nq_passages.tar.gz  100%[===================>]  33.61M  38.5MB/s    in 0.9s
#
# 2022-02-01 16:57:16 (38.5 MB/s) - ‘open_domain_data/download/nq_passages.tar.gz’ saved [35243587/35243587]
#
# --2022-02-01 16:57:16--  https://dl.fbaipublicfiles.com/FiD/data/tqa_passages.tar.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40106382 (38M) [application/gzip]
# Saving to: ‘open_domain_data/download/tqa_passages.tar.gz’
#
# tqa_passages.tar.gz 100%[===================>]  38.25M  38.6MB/s    in 1.0s
#
# 2022-02-01 16:57:18 (38.6 MB/s) - ‘open_domain_data/download/tqa_passages.tar.gz’ saved [40106382/40106382]
#
# tqa_passages/
# tqa_passages/dev.json
# tqa_passages/test.json
# tqa_passages/train.json
# nq_passages/
# nq_passages/dev.json
# nq_passages/test.json
# nq_passages/train.json

# %%
import pandas as pd

in_csv = '/content/open_domain_data/psgs_w100.tsv'

number_lines = sum(1 for row in (open(in_csv)))

rowsize = round(number_lines / 8)

for i in range(1,number_lines,rowsize):
    c=True
    df = pd.read_csv(in_csv, header=None, nrows = rowsize, skiprows = i , delimiter='\t')
    out_csv = 'input' + str(i) + '.csv'

    df.to_csv(out_csv,
          index=False,
          header=False,
          mode='a',#append data to csv file
          chunksize=rowsize)#size of data to append for each loop
    if c:
      break

# %%
import pandas as pd

in_csv = '/content/inputt1.csv'

number_lines = sum(1 for row in (open(in_csv)))

rowsize = round(number_lines / 2)

for i in range(1,number_lines,rowsize):
    c=True
    df = pd.read_csv(in_csv, header=None, nrows = rowsize, skiprows = i )
    out_csv = 'inputtt' + str(i) + '.csv'

    df.to_csv(out_csv,
          index=False,
          header=False,
          mode='a',#append data to csv file
          chunksize=rowsize)#size of data to append for each loop
    if c:
      break

# %%
# %%shell
# ROOT="open_domain_data"
# DOWNLOAD=$ROOT/"download"
#
#
# echo "Processing ""$ROOT"
# python FiD/src/preprocess.py $DOWNLOAD $ROOT
# Out:
# Processing open_domain_data
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_system_commands.py in check_returncode(self)
#     137     if self.returncode:
#     138       raise subprocess.CalledProcessError(
# --> 139           returncode=self.returncode, cmd=self.args, output=self.output)
#     140
#     141   def _repr_pretty_(self, p, cycle):  # pylint:disable=unused-argument
#
# CalledProcessError: Command 'ROOT="open_domain_data"
# DOWNLOAD=$ROOT/"download"
#
#
# echo "Processing ""$ROOT"
# python FiD/src/preprocess.py $DOWNLOAD $ROOT' died with <Signals.SIGKILL: 9>.

# %%
# !pip install transformers==3.0.2
# Out:
# Collecting transformers==3.0.2
#   Downloading transformers-3.0.2-py3-none-any.whl (769 kB)
#      |████████████████████████████████| 769 kB 4.3 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 66.5 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (4.62.3)
# Collecting sentencepiece!=0.1.92
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 49.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (2.23.0)
# Collecting tokenizers==0.8.1.rc1
#   Downloading tokenizers-0.8.1rc1-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 55.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (1.19.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.0.2) (3.0.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.2) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.2) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.2) (7.1.2)
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.47 sentencepiece-0.1.96 tokenizers-0.8.1rc1 transformers-3.0.2

# %%
# %%shell
#
# python APE/FiD/train.py \
#   --checkpoint_dir checkpoint \
#   --train_data_path open_domain_data/NQ/train.json \
#   --dev_data_path open_domain_data/NQ/dev.json \
#   --model_size base \
#   --per_gpu_batch_size 4 \
#   --n_context 1 \
#   --name my_experiment \
#   --eval_freq 1000
# Out:
# tcmalloc: large alloc 1363296256 bytes == 0x559a14648000 @  0x7f9903b281e7 0x559a09f94f98 0x559a09f5fe27 0x559a0a0de115 0x559a0a078888 0x559a09f636f2 0x559a0a041c6e 0x559a0a078802 0x559a09f636f2 0x559a09f66926 0x559a0a0e17a3 0x559a09f63349 0x559a0a054e1d 0x559a09fd6e99 0x559a09fd1ced 0x559a09f64bda 0x559a09fd6d00 0x559a09fd19ee 0x559a09f64bda 0x559a09fd3737 0x559a09fd19ee 0x559a09fd16f3 0x559a0a09b4c2 0x559a0a09b83d 0x559a0a09b6e6 0x559a0a073163 0x559a0a072e0c 0x7f9902912bf7 0x559a0a072cea
# tcmalloc: large alloc 1363296256 bytes == 0x559a65a6c000 @  0x7f9903b281e7 0x559a09f94f98 0x559a09faa4ec 0x559a0a037e93 0x559a09f63349 0x559a09f63240 0x559a09fd70f3 0x559a09fd19ee 0x559a09f65271 0x559a09f64720 0x559a09f66698 0x559a0a043441 0x559a0a0e17d1 0x559a09f63349 0x559a0a054e1d 0x559a09fd6e99 0x559a09fd1ced 0x559a09f64bda 0x559a09fd6d00 0x559a09fd19ee 0x559a09f64bda 0x559a09fd3737 0x559a09fd19ee 0x559a09fd16f3 0x559a0a09b4c2 0x559a0a09b83d 0x559a0a09b6e6 0x559a0a073163 0x559a0a072e0c 0x7f9902912bf7 0x559a0a072cea
# [01/31/2022 17:34:42] {modeling_utils.py:768} WARNING - Some weights of FiDT5 were not initialized from the model checkpoint at t5-base and are newly initialized: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 20 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 10000it [1:46:23,  1.57it/s]
